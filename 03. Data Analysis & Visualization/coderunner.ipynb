# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(1, 5, 11)
y = x**2
print(x, y)
# Out:
# [1.  1.4 1.8 2.2 2.6 3.  3.4 3.8 4.2 4.6 5. ] [ 1.    1.96  3.24  4.84  6.76  9.   11.56 14.44 17.64 21.16 25.  ]

# %%
plt.plot(x, y)
plt.title('X vs Y')
plt.xlabel('x')
plt.ylabel('y')
plt.show()
